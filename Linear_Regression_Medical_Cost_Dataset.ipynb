# %% [markdown]
# <a href="https://colab.research.google.com/github/ShyamSundhar1411/My-ML-Notebooks/blob/master/Linear_Regression_Medical_Cost_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Cleaning

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_encoded = pd.get_dummies(dataset)

# %% [markdown]
# ## Training and Test Set

# %%
x = insurance_encoded.drop("charges",axis=1)

# %%
x
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes  \
# 0      19  27.900         0           1         0          0           1
# 1      18  33.770         1           0         1          1           0
# 2      28  33.000         3           0         1          1           0
# 3      33  22.705         0           0         1          1           0
# 4      32  28.880         0           0         1          1           0
# ...   ...     ...       ...         ...       ...        ...         ...
# 1333   50  30.970         3           0         1          1           0
# 1334   18  31.920         0           1         0          1           0
# 1335   18  36.850         0           1         0          1           0
# 1336   21  25.800         0           1         0          1           0
# 1337   61  29.070         0           1         0          0           1
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# ...

# %%
y = insurance_encoded['charges']

# %% [markdown]
# ## Train Test Split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# ## Building Model

# %%
x_train.shape
# Out:
# (1070, 11)

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100,input_shape = (11,)),
    tf.keras.layers.Dense(50),
    tf.keras.layers.Dense(1)
])
model.compile(loss = tf.keras.losses.mae,optimizer = tf.keras.optimizers.Adam(),metrics = ['mae'])

# %%
model.fit(x_train,y_train,epochs = 100)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 1s 3ms/step - loss: 13226.0586 - mae: 13226.0586
# Epoch 2/100
# 34/34 [==============================] - 0s 4ms/step - loss: 12759.5791 - mae: 12759.5791
# Epoch 3/100
# 34/34 [==============================] - 0s 3ms/step - loss: 11512.4619 - mae: 11512.4619
# Epoch 4/100
# 34/34 [==============================] - 0s 3ms/step - loss: 9273.3809 - mae: 9273.3809
# Epoch 5/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7611.5620 - mae: 7611.5620
# Epoch 6/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7403.2988 - mae: 7403.2988
# Epoch 7/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7370.0552 - mae: 7370.0552
# Epoch 8/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7337.6440 - mae: 7337.6440
# Epoch 9/100
# 34/34 [==============================] - 0s 3ms/step - loss: 7304.6719 - mae: 7304.6719
# Epoch 10/100
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 3600.2981 - mae: 3600.2981
# [3600.298095703125, 3600.298095703125]

# %%
tf.random.set_seed(42)
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(100,input_shape = (11,)),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1),
])
model_2.compile(loss = tf.keras.losses.mae,optimizer = tf.keras.optimizers.Adam(),metrics = ["mae"])

# %%
model_2.fit(x_train,y_train,epochs = 400)
# Out:
# Epoch 1/400
# 34/34 [==============================] - 1s 3ms/step - loss: 13273.1602 - mae: 13273.1602
# Epoch 2/400
# 34/34 [==============================] - 0s 3ms/step - loss: 13104.4297 - mae: 13104.4297
# Epoch 3/400
# 34/34 [==============================] - 0s 3ms/step - loss: 12749.5420 - mae: 12749.5420
# Epoch 4/400
# 34/34 [==============================] - 0s 3ms/step - loss: 12055.7510 - mae: 12055.7510
# Epoch 5/400
# 34/34 [==============================] - 0s 4ms/step - loss: 10905.8154 - mae: 10905.8154
# Epoch 6/400
# 34/34 [==============================] - 0s 3ms/step - loss: 9457.7217 - mae: 9457.7217
# Epoch 7/400
# 34/34 [==============================] - 0s 3ms/step - loss: 8147.6543 - mae: 8147.6543
# Epoch 8/400
# 34/34 [==============================] - 0s 3ms/step - loss: 7528.8408 - mae: 7528.8408
# Epoch 9/400
# 34/34 [==============================] - 0s 3ms/step - loss: 7429.1528 - mae: 7429.1528
# Epoch 10/400
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ykabel("loss")
plt.xlabel("epochs")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-658e28d59ef3> in <module>
# ----> 1 pd.DataFrame(history.history).plot()
#       2 plt.ykabel("loss")
#       3 plt.xlabel("epochs")
#
# NameError: name 'history' is not defined
